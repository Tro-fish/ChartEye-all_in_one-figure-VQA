# %%
import json
import pandas as pd

with open ("../../dataset/eval/final_validation_v2.json", 'r') as f:
    validation_data1 = json.load(f)
    validation_data1 = pd.DataFrame(validation_data1)

validation_data2 = pd.read_csv("../../dataset/eval/chem-mate-png.csv")
val_data = pd.concat([validation_data1, validation_data2], ignore_index=True)

# %%
val_data
# Out:
#                                                image_id  caption_id  \
# 0                                               7424363   8492163.0
# 1                                               7424364   8492164.0
# 2                                               7424365   8492165.0
# 3                                               7424366   8492166.0
# 4                                               7424367   8492167.0
# ...                                                 ...         ...
# 33440  1801.03849_AGraph1Average10-eps-converted-to.png         NaN
# 33441            1801.03849_GraphK-eps-converted-to.png         NaN
# 33442                            2110.02464_Figure1.png         NaN
# 33443                            2110.02464_Figure4.png         NaN
# 33444                              2110.02464_Fig_1.png         NaN
#
#                                                  caption           category  \
# 0      The coefficient of Pe2 in the small-Pe optimal...   Computer Science
# 1          The accuracy score for different window size.   Computer Science
# 2      Frequency shift due to a neutron EDM of dn =  ...   Computer Science
# 3      Comparison of LDA band structure and fit by th...            Physics
# 4      The difference between the measured β values f...            Physics
# ...                                                  ...                ...
# 33440  Stress--strain curves of the four random foam ...  cond-mat.mtrl-sci
# 33441  Time averaged HCACF vs. simulation time of the...  cond-mat.mtrl-sci
# 33442  (Top) Zero-field magnitude of transmission, (B...  cond-mat.supr-con
# 33443   Zero-field normalized real  G_1()  and imagin...  cond-mat.supr-con
# 33444  Simulated frequency dependent (a) real and (b)...  cond-mat.supr-con
#
#          arXiv_id          label  \
# 0      1710.00646            NaN
# 1      2005.13754            NaN
# 2       1808.0958            NaN
# 3      2007.00901            NaN
# 4      1905.02166            NaN
# ...           ...            ...
# 33440  1801.03849     fig:Comp10
# 33441  1801.03849   fig:ThermalK
# 33442  2110.02464  fig:zerofield
# 33443  2110.02464           fig4
# 33444  2110.02464       fig:fig1
#
#                                                  context
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 33440  ['longing to the type A, is related to the clo...
# 33441  ['raphK-eps-converted-to.pdfTime averaged HCAC...
# 33442  ['rface~LI_PRB_2019, we expect $ - $W to posse...
# 33443  ['he normalized $ G_n() =1 $ for the normal fr...
# 33444  ['nce as\tG() = G_s + f(G_N -G_s)(1+2 iG_s)0.5...
#
# [33445 rows x 7 columns]
